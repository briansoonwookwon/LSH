# %% [markdown]
# # Visualizations
#
# ## False-Positive Visualization for Bloom Filters

# %%
from utils.visualizations import BloomFilter, calculate_false_positive_rate, plot_false_positive_rate_vs_hash_functions

# %%
# run code to generate and save plot
plot_false_positive_rate_vs_hash_functions(10**7, 0.02, 12)
